# %% [markdown]
# ## Reinforcement Learning Strategy for Algorithmic Trading

# %%
# Importing the libraries
from sentiment_lib import *

# Parameters
time_window = 60
ticker = "ORCL"
model = 'rppo'
base_path = "normal"

# %%
# Importing the datasets
train_df = pd.read_csv(f"rl_dfs/train/{ticker}.csv", index_col=0)
train_df.index = pd.to_datetime(train_df.index)

test_df = pd.read_csv(f"rl_dfs/test/{ticker}.csv", index_col=0)
test_df.index = pd.to_datetime(test_df.index)

# Number of steps for each iteration
num_of_steps = train_df.shape[0] - time_window
print(f"Number of steps: {num_of_steps}")
# Out:
# Number of steps: 47233

# %%
# Parameters for training environment
train_kwargs = {
    "data": train_df,
    "ticker":ticker, 
    "time_window":time_window,
    "trade_cost":0,
    "reward_logic":"log_position",
    "reward_scale":1E4,
    "only_long":False,
    "verbose":False
}

# Parameters for testing environment
test_kwargs = {
    "data": test_df,
    "ticker":ticker, 
    "time_window":time_window,
    "trade_cost":0,
    "reward_logic":"log_position",
    "reward_scale":1E4,
    "only_long":False,
    "verbose":False
}

# Model parameters
model_parameters = {
    'n_steps': 60,
    'gamma': 0.995,
    'ent_coef': 0.005,
    'learning_rate': 0.0003,
    "batch_size": 60
}

# Policy parameters
policy_kwargs = dict(
    net_arch=[dict(vf=[128, 128, 128], pi=[128, 128])],
    lstm_hidden_size=256,
    n_lstm_layers=2
)

# %%
# Creating the pipeline and its processes
mt = MultiProcessingPipeline(ticker=ticker,
                             train_kwargs=train_kwargs, 
                             test_kwargs=test_kwargs,
                             n_process=3,
                             model=model,
                             base_path=base_path)

now = datetime.now()
mt.create_process_conditions(model_parameters, 
                             policy_parameters=policy_kwargs,
                             policy="MultiInputLstmPolicy", 
                             total_timesteps = num_of_steps*3)
# Out:
# Creating process  0
#
# Creating process  1
#
# Creating process  2

# %%
today = now.strftime("%Y%m%d")
now_str = f"{now.hour}h{now.minute}"
log_paths = os.path.join(RESULTS_DIR, base_path, ticker,today, now_str, model)
tensorboard_command = f"tensorboard --logdir {log_paths} --port 6006"

print("source .venv/bin/activate")
print(tensorboard_command)
# Out:
# source .venv/bin/activate
# tensorboard --logdir results/normal/ORCL/20250301/16h44/rppo --port 6006

# %%
# Training and testing the model
start = datetime.now()
mt.multi_tasking()

print(f"Training and testing time: {datetime.now() - start}")
# Out:
# Successfully load model results/normal/ORCL/20250301/16h44/rppo_1/agent_rppo.zip
# Successfully load model results/normal/ORCL/20250301/16h44/rppo_2/agent_rppo.zip
# Successfully load model results/normal/ORCL/20250301/16h44/rppo_0/agent_rppo.zip
# Training and testing time: 4:46:41.380687

# %%
# Getting the results
mt.get_results()
# Out:
# Results of process 1
#
# ==== Final Metrics ====
# Total Return : 0.95
# Sharpe Ratio : -0.01
# Max Drawdown : 0.06
# Hit Ratio : 0.46
# Results of process 2
#
# ==== Final Metrics ====
# Total Return : 0.75
# Sharpe Ratio : -0.05
# Max Drawdown : 0.10
# Hit Ratio : 0.45
# Results of process 0
#
# ==== Final Metrics ====
# Total Return : 0.97
# Sharpe Ratio : -0.01
# Max Drawdown : 0.08
# Hit Ratio : 0.48
